# %%
from backtestv1 import *
t=fund_backTest("2021-01-01", "2021-01-30",100000)
# Out:
# Welcome to use Wind Quant API for Python (WindPy)!
#
# COPYRIGHT (C) 2020 WIND INFORMATION CO., LTD. ALL RIGHTS RESERVED.
# IN NO CIRCUMSTANCE SHALL WIND BE RESPONSIBLE FOR ANY DAMAGES OR LOSSES CAUSED BY USING WIND QUANT API FOR Python.

# %%
t.buy('000051.OF',5000,'2021-01-04')

t.buy_list(['020011.OF', '001208.OF', '001473.OF'],'2021-01-08')

t.buy('000051.OF',5000,'2021-01-11')

t.sell('020011.OF',2000,'2021-01-15')

# %%
#t.buy('000051.OF',1200,'2021-01-07')

# %%
t.handle_data()
# Out:
# 回测日期为：2021-01-04,当日持仓市值为：8826.00,总资产为：100000.00
# 持仓为：000051.OF,数量：5000.00000，该基金当日净值为：1.76520
# 回测日期为：2021-01-05,当日持仓市值为：8986.00,总资产为：100160.00
# 持仓为：000051.OF,数量：5000.00000，该基金当日净值为：1.79720
# 回测日期为：2021-01-06,当日持仓市值为：9064.00,总资产为：100238.00
# 持仓为：000051.OF,数量：5000.00000，该基金当日净值为：1.81280
# 回测日期为：2021-01-07,当日持仓市值为：9216.50,总资产为：100390.50
# 持仓为：000051.OF,数量：5000.00000，该基金当日净值为：1.84330
# 回测日期为：2021-01-08,当日持仓市值为：100357.12,总资产为：100362.00
# 持仓为：000051.OF,数量：5000.00000，该基金当日净值为：1.83760
# 持仓为：020011.OF,数量：23754.00000，该基金当日净值为：1.27940
# 持仓为：001208.OF,数量：17160.00000，该基金当日净值为：1.77100
# 持仓为：001473.OF,数量：9628.00000，该基金当日净值为：3.15620
# 回测日期为：2021-01-11,当日持仓市值为：108660.70,总资产为：108665.58
# 持仓为：000051.OF,数量：10000.00000，该基金当日净值为：1.82020
# 持仓为：020011.OF,数量：23754.00000，该基金当日净值为：1.26700
# 持仓为：001208.OF,数量：17160.00000，该基金当日净值为：1.76500
# 持仓为：001473.OF,数量：9628.00000，该基金当日净值为：3.12370
# 回测日期为：2021-01-12,当日持仓市值为：110855.62,总资产为：110860.50
# 持仓为：000051.OF,数量：10000.00000，该基金当日净值为：1.86960
# ...

# %%
'{:.2f}%'.format(-0.15*100)
# Out:
# '-15.00%'
